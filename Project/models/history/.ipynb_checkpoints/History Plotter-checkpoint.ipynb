# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# data = pd.read_csv(f'history_mlp_1000_200-150-120_7x7_rot_ellipse_flp_cut_dshift1_shift1_bia_int2_ned_ncl_g_s1_latestopping.csv')
data = pd.read_csv(f'history_mlp_1000_200-150-120_7x7_rot_ellipse_flp_cut_dshift1_shift1_bia_int1_edg_ncl_g_s1_neuEdge.csv')
print(list(data.columns))
# Out:
# ['epoch', 'loss', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse']

# %%
fig, ax = plt.subplots(figsize = (18, 10))
reds = iter(['maroon', 'green', 'steelblue', 'lightcoral'])
# '''
for i in range(2):
    data = pd.read_csv(f'history_mlp_1000_200-200-200-200-200_7x7_rot_ellipse_flp_cut_dshift1_shift1_bia_int1_edg_ncl_g_s{i+1}_neuEdge.csv')
    color = next(reds)
    data['val_loss'].plot(color=color)
    data['loss'].plot(ls='--', color=color)
    lowest_value = min(data['val_loss'])
    plt.plot([max(0, data['loss'].shape[0]-26), data['loss'].shape[0]-1], [lowest_value, lowest_value], color=color, ls='-.', lw=0.5)
'''
color = next(reds)
data = pd.read_csv(f'history_mlp_1000_200-200-200-200-200_7x7_rot_ellipse_flp_cut_dshift1_shift1_bia_int1_edg_ncl_g_s2_neuEdge.csv')
data['val_loss'].plot(color=color)
data['loss'].plot(ls='--', color=color)
lowest_value = min(data['val_loss'])
plt.plot([max(0, data['loss'].shape[0]-26), data['loss'].shape[0]-1], [lowest_value, lowest_value], color=color, ls='-.', lw=0.5)
# '''
ax.set_ylim([0.0005, 0.001])
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18, 10))
reds = iter(['maroon', 'green', 'steelblue', 'lightcoral'])
for i in range(3):
    data = pd.read_csv(f'history_mlp_1000_200-150-120_7x7_rot_ellipse_flp_cut_dshift1_shift1_bia_int2_ned_ncl_g_s{i+1}.csv')
    color = next(reds)
    data['val_loss'].plot(color=color)
    data['loss'].plot(ls='--', color=color)
ax.set_ylim([0.0005, 0.0010])
plt.show()
