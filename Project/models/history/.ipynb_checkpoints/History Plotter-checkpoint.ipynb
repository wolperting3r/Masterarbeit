# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os

# %%
# Get list of files
list_of_files = glob.glob('./*.csv')
files = []
# Get 4 newest files
for i in range(5):
    latest_file = max(list_of_files, key=os.path.getctime)
    files.append(latest_file)
    list_of_files.remove(latest_file)
for f in files:
    print(f)
# Out:
# ./history_mlp_1000_80_3x3_nrt_circle_nfp_nct_dshift0_bia_ned_ncl_s1.csv
# ./history_mlp_1000_80_5x5_rot_circle_flp_cut_dshift0_shift1_bia_ned_ncl_s1.csv
# ./history_mlp_1000_80_9x9_nrt_circle_nfp_nct_dshift0_bia_ned_ncl_s1.csv
# ./history_mlp_1000_80_7x7_nrt_circle_nfp_nct_dshift0_bia_ned_ncl_s1.csv
# ./history_mlp_1000_80_5x5_nrt_circle_nfp_nct_dshift0_bia_ned_ncl_s1.csv

# %%
data = pd.read_csv(f'history_mlp_1000_200-150-120_7x7_rot_ellipse_flp_cut_dshift1_shift1_bia_int1_edg_ncl_g_s1_neuEdge.csv')
print(list(data.columns))
# Out:
# ['epoch', 'loss', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse']

# %%
fig, ax = plt.subplots(figsize = (18, 10))
reds = iter(['maroon', 'green', 'steelblue', 'lightcoral', 'cyan', 'darkviolet', 'indigo', 'chocolate'])
# '''
for f in files:
    data = pd.read_csv(f)
    color = next(reds)
    data['val_loss'].plot(color=color, label=f)
    data['loss'].plot(ls='--', color=color, lw=0.5)
    lowest_value = min(data['val_loss'])
    print(f'{f}:\t{lowest_value:.2E}')
    plt.plot([max(0, data['loss'].shape[0]-26), data['loss'].shape[0]-1], [lowest_value, lowest_value], color=color, ls='-.', lw=0.5)
plt.legend()
ax.set_yscale('log')
# ax.set_ylim([1e-6, 1e-2])
ax.set_ylim([1.5e-5, 3e-5])
# ax.set_ylim([0.0009, 0.0014])
plt.grid()
plt.show()
# Out:
# ./history_mlp_1000_80_3x3_nrt_circle_nfp_nct_dshift0_bia_ned_ncl_s1.csv:	5.19E-04
# ./history_mlp_1000_80_5x5_rot_circle_flp_cut_dshift0_shift1_bia_ned_ncl_s1.csv:	1.59E-05
# ./history_mlp_1000_80_9x9_nrt_circle_nfp_nct_dshift0_bia_ned_ncl_s1.csv:	9.02E-06
# ./history_mlp_1000_80_7x7_nrt_circle_nfp_nct_dshift0_bia_ned_ncl_s1.csv:	1.63E-05
# ./history_mlp_1000_80_5x5_nrt_circle_nfp_nct_dshift0_bia_ned_ncl_s1.csv:	6.40E-05
